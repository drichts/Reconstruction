# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import general_functions as gen

energy = 40  # Choices: 40, 120 kVp

directory = '/home/knoll/LDAData/ESF'
folder = f'ESF_{energy}kVp'
air_folder = f'airscan_60s_{energy}kVp'

# Open the image
raw_data = np.load(os.path.join(directory, folder, 'Data', 'data.npy'))
air = np.load(os.path.join(directory, air_folder, 'Data', 'data.npy'))

# Dead pixel mask
dpm = np.load('/home/knoll/LDAData/dead_pixel_mask.npy')

# Correct the data
data = np.log(air) - np.log(raw_data)
data = gen.correct_dead_pixels(data, dead_pixel_mask=dpm)

data = data[:, :, 6]

# Show the image
fig = plt.figure(figsize=(12, 4))
plt.imshow(data, cmap="gray_r")
plt.title("MTF CZT Image")

plt.show()

# Get the pixel size
pixel = 0.33  # [mm]
# Out:
# /home/knoll/PycharmProjects/Reconstruction/venv2/lib/python3.6/site-packages/ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in log
# /home/knoll/PycharmProjects/Reconstruction/venv2/lib/python3.6/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in subtract

# %%
## Get just the MTF portion of the scan

scan = data[:, 30:440]

# Show the zoomed image
fig = plt.figure(figsize=(12, 4))
plt.imshow(scan, cmap="gray")
plt.title("Zoomed image")
plt.show()

# %%
## Get the pixel coordinates of the edge

# Get minimum value of the background
back = scan[14:,200:]

m = np.median(back)
# print(np.median(back))
# print(np.mean(back))
# print(np.std(back))

yrng = np.arange(24)
xrng = np.arange(410)

# Bottom edge pixel coord. array
edge = []

# Get the pixel coordinates of the bottom edge
for c in xrng:
    for r in yrng:
        if scan[r,c] < m+0.15:
            edge.append([r,c])
            break

edge = np.array(edge, subok=True)
print(edge)
# Out:
# [[ 20   0]
#  [ 20   1]
#  [ 20   2]
#  [ 20   3]
#  [ 20   4]
#  [ 20   5]
#  [ 20   6]
#  [ 20   7]
#  [ 20   8]
#  [ 20   9]
#  [ 20  10]
#  [ 20  11]
#  [ 20  12]
#  [ 20  13]
#  [ 20  14]
#  [ 20  15]
#  [ 20  16]
#  [ 20  17]
#  [ 20  18]
#  [ 20  19]
#  [ 20  20]
#  [ 20  21]
#  [ 19  22]
#  [ 19  23]
#  [ 19  24]
#  [ 19  25]
#  [ 19  26]
#  [ 19  27]
#  [ 19  28]
#  [ 19  29]
#  [ 19  30]
#  [ 19  31]
#  [ 19  32]
#  [ 19  33]
#  [ 19  34]
#  [ 19  35]
#  [ 19  36]
#  [ 19  37]
#  [ 19  38]
#  [ 19  39]
#  [ 19  40]
#  [ 19  41]
#  [ 19  42]
#  [ 19  43]
#  [ 18  44]
#  [ 18  45]
#  [ 18  46]
#  [ 18  47]
#  [ 18  48]
#  [ 18  49]
#  [ 18  50]
#  [ 18  51]
#  [ 18  52]
#  [ 18  53]
#  [ 18  54]
#  [ 18  55]
#  [ 18  56]
#  [ 18  57]
#  [ 18  58]
#  [ 18  59]
#  [ 18  60]
#  [ 18  61]
#  [ 18  62]
#  [ 18  63]
#  [ 18  64]
#  [ 18  65]
#  [ 18  66]
#  [ 18  67]
#  [ 18  68]
#  [ 18  69]
#  [ 18  70]
#  [ 18  71]
#  [ 18  72]
#  [ 18  73]
#  [ 18  74]
#  [ 18  75]
#  [ 18  76]
#  [ 17  77]
#  [ 17  78]
#  [ 17  79]
#  [ 17  80]
#  [ 17  81]
#  [ 17  82]
#  [ 17  83]
#  [ 17  84]
#  [ 17  85]
#  [ 17  86]
#  [ 17  87]
#  [ 17  88]
#  [ 17  89]
#  [ 17  90]
#  [ 17  91]
#  [ 17  92]
#  [ 17  93]
#  [ 17  94]
#  [ 17  95]
#  [ 17  96]
#  [ 17  97]
#  [ 17  98]
#  [ 17  99]
#  [ 17 100]
#  [ 17 101]
#  [ 17 102]
#  [ 17 103]
#  [ 17 104]
#  [ 17 105]
#  [ 17 106]
#  [ 17 107]
#  [ 17 108]
#  [ 17 109]
#  [ 17 110]
#  [ 17 111]
#  [ 16 112]
#  [ 16 113]
#  [ 16 114]
#  [ 16 115]
#  [ 16 116]
#  [ 16 117]
#  [ 16 118]
#  [ 16 119]
#  [ 16 120]
#  [ 16 121]
#  [ 16 122]
#  [ 16 123]
#  [ 16 124]
#  [ 16 125]
#  [ 16 126]
#  [ 16 127]
#  [ 16 128]
#  [ 16 129]
#  [ 16 130]
#  [ 16 131]
#  [ 16 132]
#  [ 16 133]
#  [ 16 134]
#  [ 16 135]
#  [ 16 136]
#  [ 15 137]
#  [ 15 138]
#  [ 15 139]
#  [ 15 140]
#  [ 15 141]
#  [ 15 142]
#  [ 15 143]
#  [ 15 144]
#  [ 15 145]
#  [ 15 146]
#  [ 15 147]
#  [ 15 148]
#  [ 15 149]
#  [ 15 150]
#  [ 15 151]
#  [ 15 152]
#  [ 15 153]
#  [ 15 154]
#  [ 15 155]
#  [ 15 156]
#  [ 15 157]
#  [ 15 158]
#  [ 15 159]
#  [ 15 160]
#  [ 15 161]
#  [ 15 162]
#  [ 15 163]
#  [ 15 164]
#  [ 15 165]
#  [ 15 166]
#  [ 14 167]
#  [ 14 168]
#  [ 14 169]
#  [ 14 170]
#  [ 14 171]
#  [ 14 172]
#  [ 14 173]
#  [ 14 174]
#  [ 14 175]
#  [ 14 176]
#  [ 14 177]
#  [ 14 178]
#  [ 14 179]
#  [ 14 180]
#  [ 14 181]
#  [ 14 182]
#  [ 14 183]
#  [ 14 184]
#  [ 14 185]
#  [ 14 186]
#  [ 14 187]
#  [ 14 188]
#  [ 14 189]
#  [ 14 190]
#  [ 14 191]
#  [ 14 192]
#  [ 14 193]
#  [ 14 194]
#  [ 14 195]
#  [ 14 196]
#  [ 14 197]
#  [ 14 198]
#  [ 13 199]
#  [ 13 200]
#  [ 13 201]
#  [ 13 202]
#  [ 13 203]
#  [ 13 204]
#  [ 13 205]
#  [ 13 206]
#  [ 13 207]
#  [ 13 208]
#  [ 13 209]
#  [ 13 210]
#  [ 13 211]
#  [ 13 212]
#  [ 13 213]
#  [ 13 214]
#  [ 13 215]
#  [ 13 216]
#  [ 13 217]
#  [ 13 218]
#  [ 13 219]
#  [ 13 220]
#  [ 13 221]
#  [ 13 222]
#  [ 13 223]
#  [ 13 224]
#  [ 13 225]
#  [ 13 226]
#  [ 13 227]
#  [ 13 228]
#  [ 13 229]
#  [ 12 230]
#  [ 12 231]
#  [ 12 232]
#  [ 12 233]
#  [ 12 234]
#  [ 13 235]
#  [ 12 236]
#  [ 12 237]
#  [ 12 238]
#  [ 12 239]
#  [ 12 240]
#  [ 12 241]
#  [ 12 242]
#  [ 12 243]
#  [ 12 244]
#  [ 12 245]
#  [ 12 246]
#  [ 12 247]
#  [ 12 248]
#  [ 12 249]
#  [ 12 250]
#  [ 12 251]
#  [ 12 252]
#  [ 12 253]
#  [ 12 254]
#  [ 12 255]
#  [ 12 256]
#  [ 12 257]
#  [ 11 258]
#  [ 11 259]
#  [ 11 260]
#  [ 11 261]
#  [ 11 262]
#  [ 11 263]
#  [ 11 264]
#  [ 11 265]
#  [ 11 266]
#  [ 11 267]
#  [ 11 268]
#  [ 11 269]
#  [ 11 270]
#  [ 11 271]
#  [ 11 272]
#  [ 11 273]
#  [ 11 274]
#  [ 11 275]
#  [ 11 276]
#  [ 11 277]
#  [ 11 278]
#  [ 11 279]
#  [ 11 280]
#  [ 11 281]
#  [ 11 282]
#  [ 11 283]
#  [ 11 284]
#  [ 10 285]
#  [ 10 286]
#  [ 10 287]
#  [ 10 288]
#  [ 10 289]
#  [ 10 290]
#  [ 10 291]
#  [ 10 292]
#  [ 10 293]
#  [ 10 294]
#  [ 10 295]
#  [ 10 296]
#  [ 10 297]
#  [ 10 298]
#  [ 10 299]
#  [ 10 300]
#  [ 10 301]
#  [ 10 302]
#  [ 10 303]
#  [ 10 304]
#  [ 10 305]
#  [ 10 306]
#  [ 10 307]
#  [ 10 308]
#  [ 10 309]
#  [ 10 310]
#  [ 10 311]
#  [ 10 312]
#  [ 10 313]
#  [ 10 314]
#  [ 10 315]
#  [  9 316]
#  [  9 317]
#  [  9 318]
#  [  9 319]
#  [  9 320]
#  [  9 321]
#  [  9 322]
#  [  9 323]
#  [  9 324]
#  [  9 325]
#  [  9 326]
#  [  9 327]
#  [  9 328]
#  [  9 329]
#  [  9 330]
#  [  9 331]
#  [  9 332]
#  [  9 333]
#  [  9 334]
#  [  9 335]
#  [  9 336]
#  [  9 337]
#  [  9 338]
#  [  9 339]
#  [  9 340]
#  [  9 341]
#  [  9 342]
#  [  9 343]
#  [  9 344]
#  [  9 345]
#  [  9 346]
#  [  9 347]
#  [  8 348]
#  [  8 349]
#  [  8 350]
#  [  8 351]
#  [  8 352]
#  [  8 353]
#  [  8 354]
#  [  8 355]
#  [  8 356]
#  [  8 357]
#  [  8 358]
#  [  8 359]
#  [  8 360]
#  [  8 361]
#  [  8 362]
#  [  8 363]
#  [  8 364]
#  [  8 365]
#  [  8 366]
#  [  8 367]
#  [  8 368]
#  [  8 369]
#  [  8 370]
#  [  8 371]
#  [  8 372]
#  [  7 373]
#  [  7 374]
#  [  7 375]
#  [  7 376]
#  [  7 377]
#  [  7 378]
#  [  7 379]
#  [  7 380]
#  [  7 381]
#  [  7 382]
#  [  7 383]
#  [  7 384]
#  [  7 385]
#  [  7 386]
#  [  7 387]
#  [  7 388]
#  [  7 389]
#  [  7 390]
#  [  7 391]
#  [  7 392]
#  [  7 393]
#  [  7 394]
#  [  7 395]
#  [  7 396]
#  [  7 397]
#  [  6 398]
#  [  6 399]
#  [  6 400]
#  [  7 401]
#  [  6 402]
#  [  7 403]
#  [  6 404]
#  [  6 405]
#  [  6 406]
#  [  6 407]
#  [  6 408]
#  [  6 409]]

# %%
## Calculate Nave for both edges using 1/tan(alpha)
## tan(alpha) = opp/adj
## Nave = adj/opp

# Calculate alpha for the edge relative to the horizontal axis
adj = np.ptp(edge[:,1])
opp = np.ptp(edge[:,0])

Nave = int(round(adj/opp))

# %%
## Create a number of oversampled edge functions for both edges

# Number of edge function for both edges
num = int(len(edge)/Nave)

# Array for the oversampled edge functions
EF = []

# Edge functions for the bottom edge
current = []
x = 0
for i in range(num):
    current = []
    x = edge[i*Nave]
    for j in range(x[0]-4, x[0]+4, 1):
        for k in range(Nave):
            current.append(scan[j, x[1]+k])
    EF.append(current)

EF = np.array(EF, subok=True)

# %%
## Average edge functions into one function
ESF = np.mean(EF, axis=0)

# Find the approximate edge within CE
mid = 0
for idx, val in enumerate(ESF):
    if val < m+0.3:
        mid = idx
        break

## Take the derivative of each by convolving with [-0.5 0 0.5] to get the LSF
der = [-0.5, 0, 0.5]
LSF = np.convolve(ESF, der)
LSF = np.absolute(LSF)
LSF = LSF[25:-25]    # Take just the middle around the edge

# %%
# Plot the line and edge functions
f, axarr = plt.subplots(1, 2)
axarr[0].plot(LSF)
axarr[0].set_title("LSF")
axarr[1].plot(ESF)
axarr[1].set_title("ESF")

plt.setp([a.get_xticklabels() for a in axarr], visible=False)
plt.show()

# %%
from scipy.fftpack import fft

# Find M
M = len(LSF)


# Get the frequencies to plot the MTF of the bottom edge over
freq = np.linspace(0,M/2,int(M/2))
freq = freq*Nave/(2*M*0.33)

# Calculate the MTF of the cathode side
mtf = fft(LSF)
mtf = np.absolute(mtf)
mtf = mtf[0:int(M/2)]
mtf = np.divide(mtf,np.max(mtf))

# %%
# Plot the two MTF's
fig = plt.figure()
plt.plot(freq,mtf)
plt.title("MTF")
plt.ylabel("MTF")
plt.xlabel("Spatial frequency (mm$^{-1}$)")
plt.show()

limit = np.argmin(np.abs(mtf[0:10] - 0.1))
print(f'The limiting spatial frequency: {freq[8]:.2f} lp/mm')
# Out:
# The limiting spatial frequency: 1.93 lp/mm
