# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def sigmoid(xpts):
    return 100 / (1 + np.exp(-1*xpts))

xpts1 = np.linspace(-10, 10, 100)
# xpts2 = np.linspace(40, 60, 100)

sns.set_style('whitegrid')

fig1 = plt.figure(figsize=(6, 4))
plt.plot(xpts1+15, sigmoid(xpts1), color='darkblue', ls='-')
plt.plot(xpts1+27, sigmoid(xpts1), color='orangered', ls='-')
plt.plot(xpts1+20, sigmoid(xpts1), color='darkblue', ls='--')
plt.plot(xpts1+22, sigmoid(xpts1), color='orangered', ls='--')

plt.arrow(19.5, 50, -4, 0, width=1, length_includes_head=True, head_length=1, color='darkblue')
plt.arrow(22.5, 50, 4, 0, width=1, length_includes_head=True, head_length=1, color='orangered')
plt.annotate('Tumour control \nincreased with\ntumour targeting', (0.05, 0.65), xycoords='axes fraction', va='center', fontsize=12)
plt.annotate('Adverse normal \ntissue effects \ndecreased by \ndrug encapsulation', (0.69, 0.34), xycoords='axes fraction', va='center', fontsize=12)
plt.legend(['Tumour control', 'Adverse normal tissue effects'])
plt.xlabel('Total dose administered', fontsize=14)
plt.ylabel('Percent response', fontsize=14)
plt.title('Nanoparticle effect on the therapeutic index', fontsize=14)
plt.yticks([0, 20, 40, 60, 80, 100])
# plt.legend(['Tumour control before', 'Adverse effect before', 'Tumour control after', 'Adverse effect after'])
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
plt.tick_params(axis='y', labelsize=12)
plt.ylim([0, 130])
plt.show()
fig1.savefig(r'D:\OneDrive - University of Victoria\Files\Grad School\Writings and Presentations\Posters\WIMP21\t_index.png', dpi=500)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

sns.set_style('white')

folder = r'D:\OneDrive - University of Victoria\Research\LDA Data\21-03-11_CT_AuNPs\phantom_scan_1\Norm CT'
wimp = r'D:\OneDrive - University of Victoria\Files\Grad School\Writings and Presentations\Posters\WIMP21'

# Load CT and K-edge image and take the 12th slice
ct = np.load(os.path.join(folder, 'CT_norm.npy'))[12, 138:438, 138:438]
au = np.load(os.path.join(folder, 'K-edge.npy'))[12, 138:438, 138:438]
au[au < 4] = 0

img = mpimg.imread(os.path.join(wimp, 'gold_phantom_border.png'))

# Creat gold colormap
# Create the colormaps
nbins = 100
c3 = (1, 0.843, 0)

gray_val = 0
gray_list = (gray_val, gray_val, gray_val)

c2_rng = [gray_list, c3]
cmap2 = colors.LinearSegmentedColormap.from_list('G78', c2_rng, N=nbins)

fig2 = plt.figure(figsize=(9, 9))

plt.imshow(img)
# ax2[0].annotate()
plt.title('Phantom layout with gold chloride', pad=-12, fontsize=26)
plt.axis('off')
plt.annotate('19.67 mg/ml', (0.57, 0.17), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate('14.75 mg/ml', (0.24, 0.17), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate('9.84 mg/ml', (0.14, 0.29), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate('6.56 mg/ml', (0.13, 0.63), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate('4.92 mg/ml', (0.25, 0.75), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate('1.97 mg/ml', (0.59, 0.75), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate('0.49 mg/ml', (0.43, 0.28), xycoords='axes fraction', va='center', fontsize=16)
plt.annotate(r'H$_2$O (all others)', (0.68, 0.5), xycoords='axes fraction', va='center', fontsize=16)
fig2.show()
fig2.savefig(r'D:\OneDrive - University of Victoria\Files\Grad School\Writings and Presentations\Posters\WIMP21\phantom_layout.png', dpi=500)



fig3 = plt.figure(figsize=(9, 7))

im1 = plt.imshow(ct, cmap='gray', vmin=-800, vmax=200)
plt.title('High-resolution anatomical imaging', pad=7, fontsize=24)
plt.axis('off')
cbar1 = plt.colorbar(im1)
cbar1.ax.set_ylabel('HU', fontsize=20, labelpad=20, rotation=-90)
cbar1.ax.tick_params(labelsize=18)
fig3.show()
fig3.savefig(r'D:\OneDrive - University of Victoria\Files\Grad School\Writings and Presentations\Posters\WIMP21\ct.png', dpi=500)


fig4 = plt.figure(figsize=(9, 7))

im2 = plt.imshow(au, cmap=cmap2, vmin=0, vmax=20)
plt.title('Simultaneous molecular imaging', pad=7, fontsize=24)
plt.axis('off')
cbar2 = plt.colorbar(im2)
cbar2.ax.set_ylabel('Gold concentration (mg/ml)', fontsize=20, labelpad=20, rotation=-90)
cbar2.ax.tick_params(labelsize=18)
fig4.show()
fig4.savefig(r'D:\OneDrive - University of Victoria\Files\Grad School\Writings and Presentations\Posters\WIMP21\k-edge-au.png', dpi=500)
# Out:
# c:\users\drich\appdata\local\programs\python\python37\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
